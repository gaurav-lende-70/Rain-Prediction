# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import joblib

# %%
df = pd.read_csv("rain.csv")

# %%
X = df.drop("RainTomorrow",axis=1)

# %%
y = df["RainTomorrow"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

# %%
model = RandomForestClassifier()

# %%
model
# Out:
# RandomForestClassifier()

# %%
joblib.dump(model,"rain.pkl")
# Out:
# ['rain.pkl']

# %%
X
# Out:
#        Temperature  Humidity  Pressure  WindSpeed  CloudCover  RainToday
# 0               24        76      1023         16          71          0
# 1               24        99      1005         25          99          0
# 2               20        46      1015          3          87          1
# 3               23        26      1022         22          32          0
# 4               39        73      1021         43          91          1
# ...            ...       ...       ...        ...         ...        ...
# 15065           18        56      1004         26          59          0
# 15066           36        31      1011         26          86          1
# 15067           29        32      1012         36          24          0
# 15068           21        56      1015         26          25          0
# 15069           28        26      1013          4          75          0
#
# [15070 rows x 6 columns]

# %%
import streamlit as st
import numpy as np
import joblib

# Load trained model
model = joblib.load("rain.pkl")

# Page Config
st.set_page_config(page_title="Rain Prediction", layout="centered")

# Title
st.title("🌍 Rain Prediction App")

# -------- User Inputs --------
Temperature = st.number_input("Temperature", min_value=0.0)
Humidity = st.number_input("Humidity", min_value=0.0)
Pressure = st.number_input("Pressure", min_value=0.0)
WindSpeed = st.number_input("WindSpeed", min_value=0.0)
CloudCover = st.number_input("CloudCover", min_value=0.0)
RainToday = st.number_input("RainToday", min_value=0, max_value=1)

# -------- Prediction --------
if st.button("Predict Tomorrow Rain"):

    input_data = np.array([[
        Temperature,
        Humidity,
        Pressure,
        WindSpeed,
        CloudCover,
        RainToday
    ]])

    prediction = model.predict(input_data)[0]
    probability = model.predict_proba(input_data)[0]

    # Output
    st.success(f"Predicted Rain: {prediction}")

    st.info(
        f"Confidence → Rain 0: {probability[0]:.2f}, "
        f"Rain 1: {probability[1]:.2f}"
    )
# Out:
# 2026-05-29 15:00:02.046 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.055 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.056 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.058 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.058 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.060 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.061 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.064 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.065 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.074 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.075 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.078 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.084 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.087 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.089 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.091 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.099 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.103 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.109 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.111 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.123 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.125 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.132 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.138 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.140 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.180 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-29 15:00:02.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\hp\\N312\\ML Deployment'
